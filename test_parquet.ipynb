# %%
import pandas as pd

# %%
df = pd.read_parquet('data/voivodeship_data.parquet')

# df_subset = pd.read_parquet('data/PL.parquet', columns=['name', "longitude", "latitude", "easy_access_zone"])

print(df.head())
print(df.shape)
# Out:
#   terc                name  parcel_machines  parcel_machines_247  \
# 0   02        DOLNOŚLĄSKIE             2689                 2362
# 1   04  KUJAWSKO-POMORSKIE             1572                 1424
# 2   06           LUBELSKIE             1518                 1379
# 3   08            LUBUSKIE              974                  888
# 4   10             ŁÓDZKIE             1971                 1728
#
#    parcel_machines_easy_access  parcel_machines_indoor  \
# 0                         2430                     365
# 1                         1448                     163
# 2                         1396                     141
# 3                          901                      88
# 4                         1762                     259
#
#    parcel_machines_outdoor  population
# 0                     2324     2868242
# 1                     1409     1984479
# 2                     1377     1996440
# 3                      886      969819
# 4                     1712     2345924
# ...
