# %%
import pandas as pd

# %%
df = pd.read_parquet('data/PL.parquet')

df_subset = pd.read_parquet('data/PL.parquet', columns=['name', 'type', "status", "longitude", "latitude", "easy_access_zone"])

print(df.head())
print(df.columns)
# Out:
#       name           type     status  longitude  latitude location_type  \
# 0   ADA01M  parcel_locker  Operating   22.26405  51.73834       Outdoor
# 1   ADA01N  parcel_locker  Operating   22.25875  51.74440       Outdoor
# 2  ADAM01N  parcel_locker  Operating   18.08788  52.26299       Outdoor
# 3   ADK01M  parcel_locker  Operating   22.69906  50.25873       Outdoor
# 4   ADM01A  parcel_locker   Disabled   20.63541  52.06923       Outdoor
#
#    payment_available                payment_type  location_247  \
# 0               True  Payments are not supported          True
# 1               True  Payments are not supported          True
# 2               True  Payments are not supported          True
# 3               True  Payments are not supported          True
# 4               True  Payments are not supported          True
#
#    easy_access_zone  ... parcel_reverse_return_send parcel_send  \
# 0              True  ...                       True        True
# ...
