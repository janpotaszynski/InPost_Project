# %%
import requests
import json
import time
import numpy as np

# %%
def fetch_inpost_points():
    base_url = "https://api-global-points.easypack24.net/v1/points"
    points = []
    page = 1

    print("Rozpoczynam pobieranie danych...")

    while True:
        # Parametry zapytania: numer strony i liczba wyników na stronę (max 500)
        params = {
            'page': page,
            'per_page': 500
        }

        try:
            response = requests.get(base_url, params=params)
            response.raise_for_status() # Rzuci błąd, jeśli status nie będzie 200

            data = response.json()
            items = data.get('items', [])

            if not items:
                break # Jeśli lista jest pusta, dotarliśmy do końca

            points.extend(items)
            print(f"Pobrano stronę {page}... (Łącznie punktów: {len(points)})")

            # Sprawdzenie czy jest kolejna strona w metadanych (jeśli API je udostępnia)
            # Jeśli nie, pętla przerwie się przy następnej pustej stronie
            if page >= data.get('total_pages', float('inf')):
                break

            page += 1
            # Krótka pauza, żeby nie przeciążyć serwera i nie dostać blokady (Rate Limiting)
            time.sleep(0.1)

        except requests.exceptions.RequestException as e:
            print(f"Wystąpił błąd podczas pobierania strony {page}: {e}")
            break

    return points

# %%
# Uruchomienie i zapis do pliku
if __name__ == "__main__":
    all_points = fetch_inpost_points()

    # Zapisujemy wszystko do pliku JSON
    with open("data/inpost_points.json", "w", encoding="utf-8") as f:
        json.dump(all_points, f, ensure_ascii=False, indent=4)

    print(f"\nGotowe! Pomyślnie pobrano {len(all_points)} punktów.")
    print("Dane zostały zapisane w pliku: inpost_points.json")
# Out:
# Rozpoczynam pobieranie danych...
# Pobrano stronę 1... (Łącznie punktów: 500)
# Pobrano stronę 2... (Łącznie punktów: 1000)
# Pobrano stronę 3... (Łącznie punktów: 1500)
# Pobrano stronę 4... (Łącznie punktów: 2000)
# Pobrano stronę 5... (Łącznie punktów: 2500)
# Pobrano stronę 6... (Łącznie punktów: 3000)
# Pobrano stronę 7... (Łącznie punktów: 3500)
# Pobrano stronę 8... (Łącznie punktów: 4000)
# Pobrano stronę 9... (Łącznie punktów: 4500)
# Pobrano stronę 10... (Łącznie punktów: 5000)
# Pobrano stronę 11... (Łącznie punktów: 5500)
# Pobrano stronę 12... (Łącznie punktów: 6000)
# Pobrano stronę 13... (Łącznie punktów: 6500)
# Pobrano stronę 14... (Łącznie punktów: 7000)
# Pobrano stronę 15... (Łącznie punktów: 7500)
# Pobrano stronę 16... (Łącznie punktów: 8000)
# Pobrano stronę 17... (Łącznie punktów: 8500)
# Pobrano stronę 18... (Łącznie punktów: 9000)
# Pobrano stronę 19... (Łącznie punktów: 9500)
# Pobrano stronę 20... (Łącznie punktów: 10000)
# Pobrano stronę 21... (Łącznie punktów: 10500)
# Pobrano stronę 22... (Łącznie punktów: 11000)
# Pobrano stronę 23... (Łącznie punktów: 11500)
# Pobrano stronę 24... (Łącznie punktów: 12000)
# Pobrano stronę 25... (Łącznie punktów: 12500)
# Pobrano stronę 26... (Łącznie punktów: 13000)
# Pobrano stronę 27... (Łącznie punktów: 13500)
# Pobrano stronę 28... (Łącznie punktów: 14000)
# Pobrano stronę 29... (Łącznie punktów: 14500)
# Pobrano stronę 30... (Łącznie punktów: 15000)
# Pobrano stronę 31... (Łącznie punktów: 15500)
# Pobrano stronę 32... (Łącznie punktów: 16000)
# Pobrano stronę 33... (Łącznie punktów: 16500)
# Pobrano stronę 34... (Łącznie punktów: 17000)
# Pobrano stronę 35... (Łącznie punktów: 17500)
# Pobrano stronę 36... (Łącznie punktów: 18000)
# Pobrano stronę 37... (Łącznie punktów: 18500)
# Pobrano stronę 38... (Łącznie punktów: 19000)
# Pobrano stronę 39... (Łącznie punktów: 19500)
# Pobrano stronę 40... (Łącznie punktów: 20000)
# Pobrano stronę 41... (Łącznie punktów: 20500)
# Pobrano stronę 42... (Łącznie punktów: 21000)
# Pobrano stronę 43... (Łącznie punktów: 21500)
# Pobrano stronę 44... (Łącznie punktów: 22000)
# Pobrano stronę 45... (Łącznie punktów: 22500)
# Pobrano stronę 46... (Łącznie punktów: 23000)
# Pobrano stronę 47... (Łącznie punktów: 23500)
# Pobrano stronę 48... (Łącznie punktów: 24000)
# Pobrano stronę 49... (Łącznie punktów: 24500)
# Pobrano stronę 50... (Łącznie punktów: 25000)
# Pobrano stronę 51... (Łącznie punktów: 25500)
# Pobrano stronę 52... (Łącznie punktów: 26000)
# Pobrano stronę 53... (Łącznie punktów: 26500)
# Pobrano stronę 54... (Łącznie punktów: 27000)
# Pobrano stronę 55... (Łącznie punktów: 27500)
# Pobrano stronę 56... (Łącznie punktów: 28000)
# Pobrano stronę 57... (Łącznie punktów: 28500)
# Pobrano stronę 58... (Łącznie punktów: 29000)
# Pobrano stronę 59... (Łącznie punktów: 29500)
# Pobrano stronę 60... (Łącznie punktów: 30000)
# Pobrano stronę 61... (Łącznie punktów: 30500)
# Pobrano stronę 62... (Łącznie punktów: 31000)
# Pobrano stronę 63... (Łącznie punktów: 31500)
# Pobrano stronę 64... (Łącznie punktów: 32000)
# Pobrano stronę 65... (Łącznie punktów: 32500)
# Pobrano stronę 66... (Łącznie punktów: 33000)
# Pobrano stronę 67... (Łącznie punktów: 33500)
# Pobrano stronę 68... (Łącznie punktów: 34000)
# Pobrano stronę 69... (Łącznie punktów: 34500)
# Pobrano stronę 70... (Łącznie punktów: 35000)
# Pobrano stronę 71... (Łącznie punktów: 35500)
# Pobrano stronę 72... (Łącznie punktów: 36000)
# Pobrano stronę 73... (Łącznie punktów: 36500)
# Pobrano stronę 74... (Łącznie punktów: 37000)
# Pobrano stronę 75... (Łącznie punktów: 37500)
# Pobrano stronę 76... (Łącznie punktów: 38000)
# Pobrano stronę 77... (Łącznie punktów: 38500)
# Pobrano stronę 78... (Łącznie punktów: 39000)
# Pobrano stronę 79... (Łącznie punktów: 39500)
# Pobrano stronę 80... (Łącznie punktów: 40000)
# Pobrano stronę 81... (Łącznie punktów: 40500)
# Pobrano stronę 82... (Łącznie punktów: 41000)
# Pobrano stronę 83... (Łącznie punktów: 41500)
# Pobrano stronę 84... (Łącznie punktów: 42000)
# Pobrano stronę 85... (Łącznie punktów: 42500)
# Pobrano stronę 86... (Łącznie punktów: 43000)
# Pobrano stronę 87... (Łącznie punktów: 43500)
# Pobrano stronę 88... (Łącznie punktów: 44000)
# Pobrano stronę 89... (Łącznie punktów: 44500)
# Pobrano stronę 90... (Łącznie punktów: 45000)
# Pobrano stronę 91... (Łącznie punktów: 45500)
# Pobrano stronę 92... (Łącznie punktów: 46000)
# Pobrano stronę 93... (Łącznie punktów: 46500)
# Pobrano stronę 94... (Łącznie punktów: 47000)
# Pobrano stronę 95... (Łącznie punktów: 47500)
# Pobrano stronę 96... (Łącznie punktów: 48000)
# Pobrano stronę 97... (Łącznie punktów: 48500)
# Pobrano stronę 98... (Łącznie punktów: 49000)
# Pobrano stronę 99... (Łącznie punktów: 49500)
# Pobrano stronę 100... (Łącznie punktów: 50000)
# Pobrano stronę 101... (Łącznie punktów: 50500)
# Pobrano stronę 102... (Łącznie punktów: 51000)
# Pobrano stronę 103... (Łącznie punktów: 51500)
# Pobrano stronę 104... (Łącznie punktów: 52000)
# Pobrano stronę 105... (Łącznie punktów: 52500)
# Pobrano stronę 106... (Łącznie punktów: 53000)
# Pobrano stronę 107... (Łącznie punktów: 53500)
# Pobrano stronę 108... (Łącznie punktów: 54000)
# Pobrano stronę 109... (Łącznie punktów: 54500)
# Pobrano stronę 110... (Łącznie punktów: 55000)
# Pobrano stronę 111... (Łącznie punktów: 55500)
# Pobrano stronę 112... (Łącznie punktów: 56000)
# Pobrano stronę 113... (Łącznie punktów: 56500)
# Pobrano stronę 114... (Łącznie punktów: 57000)
# Pobrano stronę 115... (Łącznie punktów: 57500)
# Pobrano stronę 116... (Łącznie punktów: 58000)
# Pobrano stronę 117... (Łącznie punktów: 58500)
# Pobrano stronę 118... (Łącznie punktów: 59000)
# Pobrano stronę 119... (Łącznie punktów: 59500)
# Pobrano stronę 120... (Łącznie punktów: 60000)
# Pobrano stronę 121... (Łącznie punktów: 60500)
# Pobrano stronę 122... (Łącznie punktów: 61000)
# Pobrano stronę 123... (Łącznie punktów: 61500)
# Pobrano stronę 124... (Łącznie punktów: 62000)
# Pobrano stronę 125... (Łącznie punktów: 62500)
# Pobrano stronę 126... (Łącznie punktów: 63000)
# Pobrano stronę 127... (Łącznie punktów: 63500)
# Pobrano stronę 128... (Łącznie punktów: 64000)
# Pobrano stronę 129... (Łącznie punktów: 64500)
# Pobrano stronę 130... (Łącznie punktów: 65000)
# Pobrano stronę 131... (Łącznie punktów: 65500)
# Pobrano stronę 132... (Łącznie punktów: 66000)
# Pobrano stronę 133... (Łącznie punktów: 66500)
# Pobrano stronę 134... (Łącznie punktów: 67000)
# Pobrano stronę 135... (Łącznie punktów: 67500)
# Pobrano stronę 136... (Łącznie punktów: 68000)
# Pobrano stronę 137... (Łącznie punktów: 68500)
# Pobrano stronę 138... (Łącznie punktów: 69000)
# Pobrano stronę 139... (Łącznie punktów: 69500)
# Pobrano stronę 140... (Łącznie punktów: 70000)
# Pobrano stronę 141... (Łącznie punktów: 70500)
# Pobrano stronę 142... (Łącznie punktów: 71000)
# Pobrano stronę 143... (Łącznie punktów: 71500)
# Pobrano stronę 144... (Łącznie punktów: 72000)
# Pobrano stronę 145... (Łącznie punktów: 72500)
# Pobrano stronę 146... (Łącznie punktów: 73000)
# Pobrano stronę 147... (Łącznie punktów: 73500)
# Pobrano stronę 148... (Łącznie punktów: 74000)
# Pobrano stronę 149... (Łącznie punktów: 74500)
# Pobrano stronę 150... (Łącznie punktów: 75000)
# Pobrano stronę 151... (Łącznie punktów: 75500)
# Pobrano stronę 152... (Łącznie punktów: 76000)
# Pobrano stronę 153... (Łącznie punktów: 76500)
# Pobrano stronę 154... (Łącznie punktów: 77000)
# Pobrano stronę 155... (Łącznie punktów: 77500)
# Pobrano stronę 156... (Łącznie punktów: 78000)
# Pobrano stronę 157... (Łącznie punktów: 78500)
# Pobrano stronę 158... (Łącznie punktów: 79000)
# Pobrano stronę 159... (Łącznie punktów: 79500)
# Pobrano stronę 160... (Łącznie punktów: 80000)
# Pobrano stronę 161... (Łącznie punktów: 80500)
# Pobrano stronę 162... (Łącznie punktów: 81000)
# Pobrano stronę 163... (Łącznie punktów: 81500)
# Pobrano stronę 164... (Łącznie punktów: 82000)
# Pobrano stronę 165... (Łącznie punktów: 82500)
# Pobrano stronę 166... (Łącznie punktów: 83000)
# Pobrano stronę 167... (Łącznie punktów: 83500)
# Pobrano stronę 168... (Łącznie punktów: 84000)
# Pobrano stronę 169... (Łącznie punktów: 84500)
# Pobrano stronę 170... (Łącznie punktów: 85000)
# Pobrano stronę 171... (Łącznie punktów: 85500)
# Pobrano stronę 172... (Łącznie punktów: 86000)
# Pobrano stronę 173... (Łącznie punktów: 86500)
# Pobrano stronę 174... (Łącznie punktów: 87000)
# Pobrano stronę 175... (Łącznie punktów: 87500)
# Pobrano stronę 176... (Łącznie punktów: 88000)
# Pobrano stronę 177... (Łącznie punktów: 88500)
# Pobrano stronę 178... (Łącznie punktów: 89000)
# Pobrano stronę 179... (Łącznie punktów: 89500)
# Pobrano stronę 180... (Łącznie punktów: 90000)
# Pobrano stronę 181... (Łącznie punktów: 90500)
# Pobrano stronę 182... (Łącznie punktów: 91000)
# Pobrano stronę 183... (Łącznie punktów: 91500)
# Pobrano stronę 184... (Łącznie punktów: 92000)
# Pobrano stronę 185... (Łącznie punktów: 92500)
# Pobrano stronę 186... (Łącznie punktów: 93000)
# Pobrano stronę 187... (Łącznie punktów: 93500)
# Pobrano stronę 188... (Łącznie punktów: 94000)
# Pobrano stronę 189... (Łącznie punktów: 94500)
# Pobrano stronę 190... (Łącznie punktów: 95000)
# Pobrano stronę 191... (Łącznie punktów: 95500)
# Pobrano stronę 192... (Łącznie punktów: 96000)
# Pobrano stronę 193... (Łącznie punktów: 96500)
# Pobrano stronę 194... (Łącznie punktów: 97000)
# Pobrano stronę 195... (Łącznie punktów: 97500)
# Pobrano stronę 196... (Łącznie punktów: 98000)
# Pobrano stronę 197... (Łącznie punktów: 98500)
# Pobrano stronę 198... (Łącznie punktów: 99000)
# Pobrano stronę 199... (Łącznie punktów: 99500)
# Pobrano stronę 200... (Łącznie punktów: 100000)
# Pobrano stronę 201... (Łącznie punktów: 100500)
# Pobrano stronę 202... (Łącznie punktów: 101000)
# Pobrano stronę 203... (Łącznie punktów: 101500)
# Pobrano stronę 204... (Łącznie punktów: 102000)
# Pobrano stronę 205... (Łącznie punktów: 102500)
# Pobrano stronę 206... (Łącznie punktów: 103000)
# Pobrano stronę 207... (Łącznie punktów: 103500)
# Pobrano stronę 208... (Łącznie punktów: 104000)
# Pobrano stronę 209... (Łącznie punktów: 104500)
# Pobrano stronę 210... (Łącznie punktów: 105000)
# Pobrano stronę 211... (Łącznie punktów: 105500)
# Pobrano stronę 212... (Łącznie punktów: 106000)
# Pobrano stronę 213... (Łącznie punktów: 106500)
# Pobrano stronę 214... (Łącznie punktów: 107000)
# Pobrano stronę 215... (Łącznie punktów: 107500)
# Pobrano stronę 216... (Łącznie punktów: 108000)
# Pobrano stronę 217... (Łącznie punktów: 108500)
# Pobrano stronę 218... (Łącznie punktów: 109000)
# Pobrano stronę 219... (Łącznie punktów: 109500)
# Pobrano stronę 220... (Łącznie punktów: 110000)
# Pobrano stronę 221... (Łącznie punktów: 110500)
# Pobrano stronę 222... (Łącznie punktów: 111000)
# Pobrano stronę 223... (Łącznie punktów: 111500)
# Pobrano stronę 224... (Łącznie punktów: 112000)
# Pobrano stronę 225... (Łącznie punktów: 112500)
# Pobrano stronę 226... (Łącznie punktów: 113000)
# Pobrano stronę 227... (Łącznie punktów: 113500)
# Pobrano stronę 228... (Łącznie punktów: 114000)
# Pobrano stronę 229... (Łącznie punktów: 114500)
# Pobrano stronę 230... (Łącznie punktów: 115000)
# Pobrano stronę 231... (Łącznie punktów: 115500)
# Pobrano stronę 232... (Łącznie punktów: 116000)
# Pobrano stronę 233... (Łącznie punktów: 116500)
# Pobrano stronę 234... (Łącznie punktów: 117000)
# Pobrano stronę 235... (Łącznie punktów: 117500)
# Pobrano stronę 236... (Łącznie punktów: 118000)
# Pobrano stronę 237... (Łącznie punktów: 118500)
# Pobrano stronę 238... (Łącznie punktów: 119000)
# Pobrano stronę 239... (Łącznie punktów: 119500)
# Pobrano stronę 240... (Łącznie punktów: 120000)
# Pobrano stronę 241... (Łącznie punktów: 120500)
# Pobrano stronę 242... (Łącznie punktów: 121000)
# Pobrano stronę 243... (Łącznie punktów: 121500)
# Pobrano stronę 244... (Łącznie punktów: 122000)
# Pobrano stronę 245... (Łącznie punktów: 122500)
# Pobrano stronę 246... (Łącznie punktów: 123000)
# Pobrano stronę 247... (Łącznie punktów: 123500)
# Pobrano stronę 248... (Łącznie punktów: 124000)
# Pobrano stronę 249... (Łącznie punktów: 124500)
# Pobrano stronę 250... (Łącznie punktów: 125000)
# Pobrano stronę 251... (Łącznie punktów: 125500)
# Pobrano stronę 252... (Łącznie punktów: 126000)
# Pobrano stronę 253... (Łącznie punktów: 126500)
# Pobrano stronę 254... (Łącznie punktów: 127000)
# Pobrano stronę 255... (Łącznie punktów: 127500)
# Pobrano stronę 256... (Łącznie punktów: 128000)
# Pobrano stronę 257... (Łącznie punktów: 128500)
# Pobrano stronę 258... (Łącznie punktów: 129000)
# Pobrano stronę 259... (Łącznie punktów: 129500)
# Pobrano stronę 260... (Łącznie punktów: 130000)
# Pobrano stronę 261... (Łącznie punktów: 130500)
# Pobrano stronę 262... (Łącznie punktów: 131000)
# Pobrano stronę 263... (Łącznie punktów: 131500)
# Pobrano stronę 264... (Łącznie punktów: 132000)
# Pobrano stronę 265... (Łącznie punktów: 132500)
# Pobrano stronę 266... (Łącznie punktów: 133000)
# Pobrano stronę 267... (Łącznie punktów: 133500)
# Pobrano stronę 268... (Łącznie punktów: 134000)
# Pobrano stronę 269... (Łącznie punktów: 134500)
# Pobrano stronę 270... (Łącznie punktów: 135000)
# Pobrano stronę 271... (Łącznie punktów: 135500)
# Pobrano stronę 272... (Łącznie punktów: 136000)
# Pobrano stronę 273... (Łącznie punktów: 136500)
# Pobrano stronę 274... (Łącznie punktów: 137000)
# Pobrano stronę 275... (Łącznie punktów: 137500)
# Pobrano stronę 276... (Łącznie punktów: 138000)
# Pobrano stronę 277... (Łącznie punktów: 138500)
# Pobrano stronę 278... (Łącznie punktów: 139000)
# Pobrano stronę 279... (Łącznie punktów: 139500)
# Pobrano stronę 280... (Łącznie punktów: 140000)
# Pobrano stronę 281... (Łącznie punktów: 140500)
# Pobrano stronę 282... (Łącznie punktów: 141000)
# Pobrano stronę 283... (Łącznie punktów: 141500)
# Pobrano stronę 284... (Łącznie punktów: 142000)
# Pobrano stronę 285... (Łącznie punktów: 142500)
# Pobrano stronę 286... (Łącznie punktów: 143000)
# Pobrano stronę 287... (Łącznie punktów: 143500)
# Pobrano stronę 288... (Łącznie punktów: 144000)
# Pobrano stronę 289... (Łącznie punktów: 144500)
# Pobrano stronę 290... (Łącznie punktów: 145000)
# Pobrano stronę 291... (Łącznie punktów: 145500)
# Pobrano stronę 292... (Łącznie punktów: 146000)
# Pobrano stronę 293... (Łącznie punktów: 146500)
# Pobrano stronę 294... (Łącznie punktów: 147000)
# Pobrano stronę 295... (Łącznie punktów: 147500)
# Pobrano stronę 296... (Łącznie punktów: 148000)
# Pobrano stronę 297... (Łącznie punktów: 148500)
# Pobrano stronę 298... (Łącznie punktów: 149000)
# Pobrano stronę 299... (Łącznie punktów: 149500)
# Pobrano stronę 300... (Łącznie punktów: 150000)
# Pobrano stronę 301... (Łącznie punktów: 150500)
# Pobrano stronę 302... (Łącznie punktów: 151000)
# Pobrano stronę 303... (Łącznie punktów: 151500)
# Pobrano stronę 304... (Łącznie punktów: 152000)
# Pobrano stronę 305... (Łącznie punktów: 152500)
# Pobrano stronę 306... (Łącznie punktów: 153000)
# Pobrano stronę 307... (Łącznie punktów: 153130)
#
# Gotowe! Pomyślnie pobrano 153130 punktów.
# Dane zostały zapisane w pliku: inpost_points.json

# %%
all_points[126451]
# Out:
# {'href': 'https://api-global-points.easypack24.net/v1/points/GB/UK00104194',
#  'country': 'GB',
#  'name': 'UK00104194',
#  'type': ['parcel_locker'],
#  'status': 'Operating',
#  'location': {'longitude': -1.93403, 'latitude': 52.66905},
#  'location_type': 'Outdoor',
#  'location_category': 'Generic',
#  'location_date': None,
#  'location_description': 'Locker is located to the left of the main entrance.',
#  'location_description_1': None,
#  'location_description_2': None,
#  'distance': None,
#  'opening_hours': '24/7',
#  'address': {'line1': '8 Highfields Road 24/7 InPost Locker - Central Co-op Chasetown Highfields Road',
#   'line2': 'WS7 4QU Chasetown'},
#  'address_details': {'city': 'Chasetown',
#   'province': 'West Midlands',
#   'post_code': 'WS7 4QU',
#   'street': '8 Highfields Road',
#   'building_number': '24/7 InPost Locker - Central Co-op Chasetown Highfields Road',
#   'flat_number': None},
#  'phone_number': None,
#  'payment_point_descr': None,
#  'functions': ['parcel', 'parcel_collect', 'parcel_send'],
#  'partner_id': 0,
#  'is_next': False,
#  'payment_available': True,
#  'payment_type': {'3': 'Payment by cash and card'},
#  'virtual': '0',
#  'recommended_low_interest_box_machines_list': None,
#  'apm_doubled': None,
#  'location_247': True,
#  'operating_hours_extended': {'customer': None},
#  'agency': '7790',
#  'agencies_extended': [{'name': '7790'}],
#  'image_url': 'https://static.easypack24.net/points/gb/images/UK00104194.jpg',
#  'easy_access_zone': True,
#  'air_index_level': None,
#  'physical_type': 'newfm',
#  'physical_type_mapped': '004',
#  'physical_type_description': None,
#  'in_mobile_collect_excluded': False,
#  'in_mobile_send_excluded': True,
#  'in_mobile_return_excluded': True,
#  'express_delivery_send': False,
#  'express_delivery_collect': False,
#  'delivery_area_id': None,
#  'micro_area_id': None,
#  'agency_code': None,
#  'd2d_courier_area': None,
#  'd2d_courier_micro_area': None,
#  'locker_availability': {'status': 'VERY_LOW',
#   'details': {'A': 'VERY_LOW', 'B': 'VERY_LOW', 'C': 'VERY_LOW'}},
#  'supported_locker_temperatures': None,
#  'unavailability_periods': None,
#  'mondial_relay_id': '',
#  'print_in_store': None}

# %%
types = [str(point['location_type']) for point in all_points]
print(np.unique(types, return_counts=True))
# Out:
# (array(['Indoor', 'Outdoor'], dtype='<U7'), array([ 24414, 128716]))

# %%
types2 = [point['type'] for point in all_points]
fnctns = []
for tps in types2:
    for tp in tps:
        if tp not in fnctns:
            fnctns.append(tp)
print(fnctns)
# Out:
# ['parcel_locker', 'pok', 'pop', 'refrigerated_locker_machine', 'parcel_locker_superpop', 'pudo_mini']
